# %% [markdown]
# 1.Write a simple program to display numbers 0 to 6 and their squares beside them

# %%
def number(x):
    return x*x
for i in range(7):
    print("The square of ",i,"is ",number(i))
# Out:
# The square of  0 is  0
# The square of  1 is  1
# The square of  2 is  4
# The square of  3 is  9
# The square of  4 is  16
# The square of  5 is  25
# The square of  6 is  36

# %% [markdown]
# 2.Write a program to display the output shown in sheet 2

# %%
for i in(3,6):
    for j in range(1,10):
        print(i,j*5)
# Out:
# 3 5
# 3 10
# 3 15
# 3 20
# 3 25
# 3 30
# 3 35
# 3 40
# 3 45
# 6 5
# 6 10
# 6 15
# 6 20
# 6 25
# 6 30
# 6 35
# 6 40
# 6 45

# %% [markdown]
# 3.Write python code to display the info between (3) and (4)

# %%
import pandas as pd
import os
dataOriginal=pd.read_csv("sampledata.csv",skipfooter=2,engine='python')
dataOriginal['3)']=dataOriginal['Campaign name'].str.find("3)")
dataOriginal['(4']=dataOriginal['Campaign name'].str.find("(4")
dataOriginal['databetween 3 and 4']=dataOriginal.apply(lambda dataOriginal:dataOriginal['Campaign name'][dataOriginal['3)']+3:dataOriginal['(4']-1],axis=1)
dataOriginal
# Out:
#        Account                                      Campaign name  \
# 0    Zilla ITA  facebook_(1)_ITA__ITA__Fashion_(3)_Dresses_(4)...
# 1    Zilla ITA  facebook_(1)_ITA__ITA__Fashion_(3)_Dresses_(4)...
# 2    Zilla ITA  facebook_(1)_ITA__ITA__Fashion_(3)_Dresses_(4)...
# 3    Zilla ITA  facebook_(1)_ITA__ITA__Fashion_(3)_Dresses_(4)...
# 4    Zilla ITA  facebook_(1)_ITA__ITA__Fashion_(3)_Dresses_(4)...
# ..         ...                                                ...
# 324  Zilla ESP  facebook_(1)_ESP__ESP__Fashion_(3)_beachdress_...
# 325  Zilla ESP  facebook_(1)_ESP__ESP__Fashion_(3)_beachdress_...
# 326  Zilla ESP  facebook_(1)_ESP__ESP__Fashion_(3)_beachdress_...
# 327  Zilla ESP  facebook_(1)_ESP__ESP__Fashion_(3)_beachdress_...
# 328  Zilla ESP  facebook_(1)_ESP__ESP__Fashion_(3)_beachdress_...
#
#     Currency code   device                           Campaign name and device  \
# 0             EUR   Laptop  facebook_(1)_ITA__ITA__Fashion_(3)_Dresses_(4)...
# ...

# %% [markdown]
# 4.Write code to generate a random list of 10 numbers between 1 and 100 and display only those divisible by 3 in a list

# %%
import random
s=1
list1=[]
while s<=10:
    x=random.randrange(1,100)
    if x%3==0:
        s=s+1
        list1.append(x)
print(list1)
# Out:
# [75, 96, 75, 69, 99, 42, 21, 42, 6, 93]

# %% [markdown]
# 5.Create a dictionary with 10 IPL teams and their cities and convert them into a dataframe

# %%
ipl1=dict({"names":["Chennai Super Kings","Delhi Capitals","Gujarat Titans","Kolkata Knight Riders","Lucknow Super Giants","Mumbai Indians","Punjab Kings","Rajasthan Royals","Royal Challengers Bangalore","Sunrisers Hyderabad"],
           "citys":["Chennai","Delhi","Gujarat","Kolkata","Lucknow","Mumbai","Punjab","Rajasthan","Bangalore","Hyderabad"]})
pd.DataFrame(ipl1)
# Out:
#                          names      citys
# 0          Chennai Super Kings    Chennai
# 1               Delhi Capitals      Delhi
# 2               Gujarat Titans    Gujarat
# 3        Kolkata Knight Riders    Kolkata
# 4         Lucknow Super Giants    Lucknow
# 5               Mumbai Indians     Mumbai
# 6                 Punjab Kings     Punjab
# 7             Rajasthan Royals  Rajasthan
# 8  Royal Challengers Bangalore  Bangalore
# 9          Sunrisers Hyderabad  Hyderabad

# %% [markdown]
# 6.Create two 3*3 matrices with values as first 9 multiples of 3 and 5 respectively. Create a new matrix with output values as sum of the two previous matrices

# %%
import numpy as np
list1=[]
for i in range(1,10):
    x=3*i
    list1.append(x)
matrix1 = np.array(list1).reshape(3,3)
list2=[]
for i in range(1,10):
    x=5*i
    list2.append(x)
matrix2 = np.array(list2).reshape(3,3)
res=matrix1+matrix2
res
# Out:
# array([[ 8, 16, 24],
#        [32, 40, 48],
#        [56, 64, 72]])

# %% [markdown]
# 7.Write code to display rows with clicks less than 20000 [use Sample Python file]

# %%
import pandas as pd
import os
data=pd.read_csv("samplepython.csv",skipfooter=2,engine='python')
data[data["Clicks"]<20000]
# Out:
#           Date   Category  Clicks  Impressions  Conversions     Cost  \
# 8    8/25/2020      Pants   18764       213752      1279.03  2172.77
# 9    8/24/2020      Pants   14592       171286       771.37  1890.87
# 10  09-02-2020      Shoes   14316       130125       913.19  1050.31
# 11  09-01-2020      Shoes   14223       114063       932.43  1507.21
# 12   8/31/2020      Shoes   13359       146747       767.47  1101.73
# ..         ...        ...     ...          ...          ...      ...
# 95   8/28/2020  Ear rings    1088        17579        42.25   148.57
# 96   8/27/2020  Ear rings    1079        25862        32.93   277.28
# 97   8/26/2020  Ear rings    1046         3264        85.72    75.98
# 98   8/25/2020  Ear rings     991        12594        28.44   100.89
# 99   8/24/2020  Ear rings     934        23910        32.09   225.77
#
#     conversion value
# 8           43193.76
# 9           28769.70
# 10          37858.20
# 11          34241.86
# 12          31029.89
# ...

# %% [markdown]
# 8.How many rows exist with category not equal to Pants [use Sample Python file]

# %%
count_Of_not_Pants=data[data["Category"]!="Pants"].count()
count_Of_not_Pants
# Out:
# Date                90
# Category            90
# Clicks              90
# Impressions         90
# Conversions         90
# Cost                90
# conversion value    90
# dtype: int64

# %% [markdown]
# 9.Find sum of clicks and minimum of cost grouping by date and category [use Sample Python file]

# %%
sum_Click_min_cost=data.groupby(["Date","Category"]).agg({"Clicks":"sum","Cost":"min"})
sum_Click_min_cost
# Out:
#                        Clicks     Cost
# Date       Category
# 09-01-2020 Armbands      2390   471.96
#            Belts         5801   634.75
#            Caps          2107   339.82
#            Ear rings     1349   209.14
#            Pants        43705  6007.22
# ...                       ...      ...
# 9/30/2020  Shirt         3616   376.11
#            Shoes        11395  1344.83
#            Socks         8778  1077.56
#            Sunglasses    1598    86.94
#            Tie           2935   307.90
#
# [100 rows x 2 columns]

# %% [markdown]
# 10.Rename clicks column to click and save it to a new dataframe [use Sample Python file]

# %%
renameing=data.rename(columns={"Clicks":"click  and save"})
renameing
# Out:
#           Date   Category  click  and save  Impressions  Conversions     Cost  \
# 0   09-02-2020      Pants            45874       657538      1601.49  5743.20
# 1   09-01-2020      Pants            43705       696732      1751.06  6007.22
# 2    8/31/2020      Pants            40698       564526      1300.56  4941.31
# 3    9/30/2020      Pants            37060       833622      1129.56  5655.03
# 4    8/29/2020      Pants            27063       441859      1063.20  3745.99
# ..         ...        ...              ...          ...          ...      ...
# 95   8/28/2020  Ear rings             1088        17579        42.25   148.57
# 96   8/27/2020  Ear rings             1079        25862        32.93   277.28
# 97   8/26/2020  Ear rings             1046         3264        85.72    75.98
# 98   8/25/2020  Ear rings              991        12594        28.44   100.89
# 99   8/24/2020  Ear rings              934        23910        32.09   225.77
#
#     conversion value
# ...

# %% [markdown]
# 11.Sort the values by clicks desc and display the first 6 rows of that output [use Sample Python file]

# %%
df=data.sort_values(by="Clicks",ascending=False)
df.head(6)
# Out:
#          Date Category  Clicks  Impressions  Conversions     Cost  \
# 0  09-02-2020    Pants   45874       657538      1601.49  5743.20
# 1  09-01-2020    Pants   43705       696732      1751.06  6007.22
# 2   8/31/2020    Pants   40698       564526      1300.56  4941.31
# 3   9/30/2020    Pants   37060       833622      1129.56  5655.03
# 4   8/29/2020    Pants   27063       441859      1063.20  3745.99
# 5   8/28/2020    Pants   25975       407077      1107.51  3547.92
#
#    conversion value
# 0          57738.03
# 1          63966.77
# 2          49228.12
# 3          37628.61
# 4          39743.02
# 5          40862.99

# %% [markdown]
# 12.Which category had the highest revenue per order

# %%
revenue=data.groupby("Category").agg({"Category":"count","Cost":"sum"})
revenue=revenue.sort_values(by="Cost",ascending=False)
revenue.head(1)
# Out:
#           Category      Cost
# Category
# Pants           10  40567.95

# %% [markdown]
# 13.Find employees who had higher salary than their manager

# %%
import pandas as pd 
employee=pd.read_csv("employeemanger.csv")
employee['ManagerID']=employee["ManagerID"].fillna(0)
employee['ManagerID']=employee['ManagerID'].astype(int)
result=[]
try:
    for i in range(0,4):
        x=employee._get_value(i, 'ManagerID')
        if x>0:
            y=employee['Salary'].iloc[x-1]
            result.append(y)
        else:
            result.append(0)
except IndexError:
    print("done")
employee['Result']=result
employee['more'] = np.where((employee['Result'] >0) & (employee['Result'] <= employee['Salary']), employee['Name']+" has more salary than his Manager", np.nan)
employee
# Out:
#    Id       Name  Salary  ManagerID  Result  \
# 0   1       John   70000          3   60000
# 1   2  Henderson   80000          4   90000
# 2   3      Santi   60000          0       0
# 3   4     Manuel   90000          0       0
#
#                                     more
# 0  John has more salary than his Manager
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN

# %% [markdown]
# 14.Find % change in revenue for each company from 2007 to 2008 [use revenue file from DataSet-2]

# %%
revenu=pd.read_csv("revenu.csv")
grouped_by_year=revenu.groupby("Year").agg({"Revenue":"sum"})
result=grouped_by_year.iloc[1]-grouped_by_year.iloc[0]
Percent_Change=result/grouped_by_year.iloc[0]*100
Percent_Change
# Out:
# Revenue    26.666667
# dtype: float64

# %% [markdown]
# 16.Find cumulative revenue for 2021 and 2022 [use ytd file from DataSet-2]

# %%
ytd=pd.read_csv("ytd.csv")
ytd['bookingdate'] = pd.to_datetime(ytd['bookingdate'], dayfirst=True)
ytd1=ytd.sort_values(by="bookingdate")
ytd1['yyyy'] = pd.to_datetime(ytd1['bookingdate']).dt.year
ytd1['cumsum']=ytd1.groupby('yyyy').cumsum()
ytd1[['bookingdate','yyyy','revenue','cumsum']]
# Out:
#   bookingdate  yyyy  revenue  cumsum
# 0  2021-01-01  2021      100     100
# 1  2021-01-02  2021      300     400
# 2  2021-01-03  2021      200     600
# 9  2021-08-12  2021      500    1100
# 6  2021-08-13  2021      500    1600
# 8  2021-08-19  2021      800    2400
# 3  2022-01-01  2022      300     300
# 4  2022-01-02  2022      400     700
# 5  2022-01-03  2022      360    1060
# 7  2022-08-12  2022      400    1460

# %% [markdown]
# 17.Plot revenue for each month in 2021 using a suitable plot [use ytd file from DataSet-2]

# %%
from matplotlib import pyplot as  plt
ytd1['mm'] = pd.to_datetime(ytd1['bookingdate']).dt.month
ploting_data=ytd1[ytd1['yyyy']==2021]
ploting_data1=ploting_data.groupby('mm')['revenue'].sum()
datapolt=ploting_data1.to_frame(name='sum of revenue in 2021')
datapolt.reset_index()
datapolt.plot(color='green',kind="bar")
# Out:
# <AxesSubplot:xlabel='mm'>

# %% [markdown]
# 18.Write code to find country of each campaign using loc [use Sample Python file]

# %%
data1=pd.read_csv("sampledata.csv",skipfooter=2,engine='python')
data1['1)']=data1.loc[:,'Campaign name'].str.find('1)')
data1['_F']=data1.loc[:,'Campaign name'].str.find('_F')
data1['country']=data1.apply(lambda data1:data1['Campaign name'][data1['1)']+3:data1['_F']-6],axis=1)
data1
# Out:
#        Account                                      Campaign name  \
# 0    Zilla ITA  facebook_(1)_ITA__ITA__Fashion_(3)_Dresses_(4)...
# 1    Zilla ITA  facebook_(1)_ITA__ITA__Fashion_(3)_Dresses_(4)...
# 2    Zilla ITA  facebook_(1)_ITA__ITA__Fashion_(3)_Dresses_(4)...
# 3    Zilla ITA  facebook_(1)_ITA__ITA__Fashion_(3)_Dresses_(4)...
# 4    Zilla ITA  facebook_(1)_ITA__ITA__Fashion_(3)_Dresses_(4)...
# ..         ...                                                ...
# 324  Zilla ESP  facebook_(1)_ESP__ESP__Fashion_(3)_beachdress_...
# 325  Zilla ESP  facebook_(1)_ESP__ESP__Fashion_(3)_beachdress_...
# 326  Zilla ESP  facebook_(1)_ESP__ESP__Fashion_(3)_beachdress_...
# 327  Zilla ESP  facebook_(1)_ESP__ESP__Fashion_(3)_beachdress_...
# 328  Zilla ESP  facebook_(1)_ESP__ESP__Fashion_(3)_beachdress_...
#
#     Currency code   device                           Campaign name and device  \
# 0             EUR   Laptop  facebook_(1)_ITA__ITA__Fashion_(3)_Dresses_(4)...
# ...

# %% [markdown]
# 19.Replace underscore in campaign with hyphen [use Sample Python file]

# %%
data1=pd.read_csv("sampledata.csv",skipfooter=2,engine='python')
data1['Campaign name'] = data1['Campaign name'].str.replace('_','-')
data1
# Out:
#        Account                                      Campaign name  \
# 0    Zilla ITA  facebook-(1)-ITA--ITA--Fashion-(3)-Dresses-(4)...
# 1    Zilla ITA  facebook-(1)-ITA--ITA--Fashion-(3)-Dresses-(4)...
# 2    Zilla ITA  facebook-(1)-ITA--ITA--Fashion-(3)-Dresses-(4)...
# 3    Zilla ITA  facebook-(1)-ITA--ITA--Fashion-(3)-Dresses-(4)...
# 4    Zilla ITA  facebook-(1)-ITA--ITA--Fashion-(3)-Dresses-(4)...
# ..         ...                                                ...
# 324  Zilla ESP  facebook-(1)-ESP--ESP--Fashion-(3)-beachdress-...
# 325  Zilla ESP  facebook-(1)-ESP--ESP--Fashion-(3)-beachdress-...
# 326  Zilla ESP  facebook-(1)-ESP--ESP--Fashion-(3)-beachdress-...
# 327  Zilla ESP  facebook-(1)-ESP--ESP--Fashion-(3)-beachdress-...
# 328  Zilla ESP  facebook-(1)-ESP--ESP--Fashion-(3)-beachdress-...
#
#     Currency code   device                           Campaign name and device  \
# 0             EUR   Laptop  facebook_(1)_ITA__ITA__Fashion_(3)_Dresses_(4)...
# ...

# %% [markdown]
# 20.Plot the clicks data for top 10 campaigns with most clicks

# %%
from matplotlib import pyplot as  plt
sadata=pd.read_csv("sampledata.csv",skipfooter=2,engine='python')
Clicks=sadata.sort_values(by="click",ascending=False)
plotdataforclicks=Clicks.head(10)
pdfc=plotdataforclicks.groupby('Campaign name')['click'].sum()
pdfc.plot(color='green',kind="bar")
# Out:
# <AxesSubplot:xlabel='Campaign name'>

# %% [markdown]
# 21.Store the two analytical files in your directory and write code to get data only from files which contain word analytical and append them [use analytical1 and analytical 2 files from DataSet-2]

# %%
import os
dirt=os. listdir('C:\\Users\\nagam')
start_letter = 'analytical'
with_s = [x for x in dirt if x.startswith(start_letter)]
with_s
# Out:
# ['analytical1.csv', 'analytical2.csv']

# %% [markdown]
# 22.Write a program to display the country and device separated by a - [use Sample Python file]

# %%
dataOriginal2=pd.read_csv("sampledata.csv",skipfooter=2,engine='python')
dataOriginal2['1)']=dataOriginal2['Campaign name'].str.find("1)")
dataOriginal2['_F']=dataOriginal2['Campaign name'].str.find("_F")
dataOriginal2['Country']=dataOriginal2.apply(lambda dataOriginal2:dataOriginal2['Campaign name'][dataOriginal2['1)']+8:dataOriginal2['_F']-1]+"-"+dataOriginal2["device"],axis=1)
dataOriginal2
# Out:
#        Account                                      Campaign name  \
# 0    Zilla ITA  facebook_(1)_ITA__ITA__Fashion_(3)_Dresses_(4)...
# 1    Zilla ITA  facebook_(1)_ITA__ITA__Fashion_(3)_Dresses_(4)...
# 2    Zilla ITA  facebook_(1)_ITA__ITA__Fashion_(3)_Dresses_(4)...
# 3    Zilla ITA  facebook_(1)_ITA__ITA__Fashion_(3)_Dresses_(4)...
# 4    Zilla ITA  facebook_(1)_ITA__ITA__Fashion_(3)_Dresses_(4)...
# ..         ...                                                ...
# 324  Zilla ESP  facebook_(1)_ESP__ESP__Fashion_(3)_beachdress_...
# 325  Zilla ESP  facebook_(1)_ESP__ESP__Fashion_(3)_beachdress_...
# 326  Zilla ESP  facebook_(1)_ESP__ESP__Fashion_(3)_beachdress_...
# 327  Zilla ESP  facebook_(1)_ESP__ESP__Fashion_(3)_beachdress_...
# 328  Zilla ESP  facebook_(1)_ESP__ESP__Fashion_(3)_beachdress_...
#
#     Currency code   device                           Campaign name and device  \
# 0             EUR   Laptop  facebook_(1)_ITA__ITA__Fashion_(3)_Dresses_(4)...
# ...

# %% [markdown]
# 23.Write a program to print a multiplication table up to a given number. For example, if we provide 5 then it should print the multiplication table until 5, and on.

# %%
n=int(input("Enter the number"))
for  i in range(1,n+1):
    print(str(n)+"*"+str(i)+"=",n*i)
# Out:
# Enter the number6
# 6*1= 6
# 6*2= 12
# 6*3= 18
# 6*4= 24
# 6*5= 30
# 6*6= 36
